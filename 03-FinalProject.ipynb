# %% [markdown]
# # Rubric
#
# Instructions: DELETE this cell before you submit via a `git push` to your repo before deadline. This cell is for your reference only and is not needed in your report.
#
# Scoring: Out of 18 points in total.  15 points in the report.  3 points in the video summary of your report for a non-technical audience.
#
# For the report section Title & Abstract trhough Data Wrangling:
#
#   -  Each Developing => -0.5 pts
#
#   -  Each Unsatisfactory/Missing => -1 pts
#
# For the report section Data Visualizations through Documentation and Written Communication:
#
#   -  Each Developing => -1 pts
#
#   -  Each Unsatisfactory/Missing => -2 pts
#
# For the video:
#
#   -  Developing => -1.5 pts
#
#   -  Unsatisfactory/Missing => -3 pts
#
# Until the score is 0
#
# |                                                                                    | Unsatisfactory                                                                                                                                                                                                                                                                                      | Developing                                                                                                                                                                                                                                                                                                                          | Proficient                                                                                                                                                                                                                                                    | Excellent                                                                                                                                                                                                                                                                                                                                                          |
# | ---------------------------------------------------------------------------------- | --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- |
# | Title & abstract                                                                   | Title or abstract is confusing or fails to offer important details about the question, variables, context, or methods of the project.                                                                                                                                                               | Title or abstract lacks relevance or fails to offer appropriate details about the question, variables, context, or methods of the project.                                                                                                                                                                                          | Title and abstract are relevant, offering sufficient details about the research project.                                                                                                                                                                      | Title and abstract are informative, succinct, and clear. It offers specific details about the question, variables, context, and proposed methods of the study.                                                                                                                                                                                                    |
# | Background                                                                         | Did not have at least 3 reliable and relevant sources. Or relevant sources were not used in relevant ways.                                                                                                                                                                                           | A key component was not connected to the research literature. Selected literature was from unreliable sources. Literary supports were vague or ambiguous.                                                                                                                                                                           | Key research components were connected to relevant, reliable literature.                                                                                                                                                                                      | Narrative integrates critical and logical details from the peer-reviewed or other professional research literature. Each key research component is grounded to the literature. Attention is given to different perspectives, threats to validity, and opinion vs. evidence.                                                                                       |
# | Research question & hypothesis                                                     | Research issue remains unclear. The research purpose, questions, hypotheses, definitions or variables and controls are still largely undefined, or when they are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Research issue is identified, but statement is too broad or fails to establish the importance of the problem. The research purpose, questions, hypotheses, definitions or variables and controls are poorly formed, ambiguous, or not logically connected to the description of the problem. Unclear connections to the literature. | Identifies a relevant research issue. Research questions are succinctly stated, connected to the research issue, and supported by the literature. Variables and controls have been identified and described. Connections are established with the literature. | Presents a significant research problem related to the chemical sciences. Articulates clear, reasonable research questions given the purpose, design, and methods of the project. All variables and controls have been appropriately defined. Proposals are clearly supported from the research and theoretical literature. All elements are mutually supportive. |
# | Data description                                                                   | Did not have references to relevant data sources for this problem. Did not describe the data obtained at those sources.                                                                                                                                                                              | A key data source was not referenced or described in satisfactory level of detail.                                                                                                                                                                                                                                                  | All relevant data sources were referenced and described in terms of their key variables and size.                                                                                                                                                             | Multiple data sources for each aspect of the project. All data sources are fully described and referenced. The details of the descriptions also make it clear how they support the needs of the project.                                                                                                                                                          |
# | Data wrangling                                                                     | Data obviously not tidy and not clean. Or even if they are clean/tidy, there was no demonstration of that fact.                                                                                                                                                                                      | Data has some minor problems with tidiness or cleanliness. Potentially these are not problems but it wasn't fully demonstrated to be the case in the code.                                                                                                                                                                          | Data are made tidy and clean, or are clearly demonstrated to be so from download.                                                                                                                                                                             | Data wrangling is complete, but also particularly thoroughly done for a very tough case. Often free text parsing is a bear like this, and doing it well can mean a million edge cases.                                                                                                                                                                            |
# | Ethics                                                                             | No effort or just says we have no ethical concerns.                                                                                                                                                                                                                                                   | Minimal ethical section; probably just talks about data privacy and no unintended consequences discussion. Ethical concerns raised seem irrelevant.                                                                                                                                                                                 | The ethical concerns described are appropriate and sufficient.                                                                                                                                                                                                | Ethical concerns are described clearly and succinctly. This was clearly a thorough and nuanced approach to the issues.                                                                                                                                                                                                                                            |
# | Data visualizations                                                                | No plots. Or most plots don't capture useful information, or their display of information is difficult to understand. Legends, labels, axes, titles, captions, etc of most plots may be poor or missing. Most figures are not referenced in the main text.                                         | Fewer than 3 relevant plots (irrelevant to the question plots do not count). Or a few of the plots don't make sense or capture useful information. Legends, labels, axes, titles, captions, etc are illegible or inadequately describe the content in a few figures. Or a few figures are not referenced or explained inside the main text. | Plots almost all make sense and capture useful information. Legends, labels, axes, titles, captions, etc are clearly legible and adequately describe the content of the figure. Figures are referenced or explained inside the main text and not just left hanging. | Plots are beautiful and information dense. Legends, labels, axes, titles, captions, etc clearly describe the content of the figure. Figures are well integrated with the text.                                                                                                                                                                                    |
# | Data analysis and results                                                          | No analyses beyond EDA style explorations of the dataset. Or analyses presented do not help address the question/hypothesis. Or most of the analyses presented are not technically appropriate (e.g. using parametric methods for non-parametric data).                                           | Only one analysis beyond EDA. Or a few analyses presented do not address the question/hypothesis. Or a few of the analyses presented are not technically appropriate.                                                                                                                                                                | At least two analyses beyond EDA. That is, the project uses two different techniques (e.g., inference vs machine learning; or t-tests vs regression; or entire dataset vs stratified to two different proxies for the same concept are investigated). Each analysis addressed the question/hypothesis and is technically appropriate. | Many different analyses are used. Each analysis addressed an aspect of the question/hypothesis and is technically appropriate. Perhaps they use multiple datasets, or do something else to go the extra mile and address the reliability of the results.                                                                                                        |
# | Conclusion and discussion                                                          | Doesn't have a narrative/conclusions of what the report accomplished. Or very minimal conclusions, like "X was best" without anything else.                                                                                                                                                          | Has narrative/conclusions, but it feels perfunctory and lacks context. Especially if the limitations and ethics sections are largely junk or missing.                                                                                                                                                                               | Properly recapitulates the results and provides context for them. Has a sense of the limitations and ethical issues.                                                                                                                                          | Clearly recapitulates the results and provides context, including the literature/background. Has a sense of what to do next, and has good explorations of the limitations and ethics.                                                                                                                                                                              |
# | Documentation and written communication                                            | Code documentation is non-existent or perfunctory. Writing has usage errors, poor fluency, and poor rhetoric. If doc/writing are both like this you get unsatisfactory. If one is unsatisfactory and the other is developing you still get unsatisfactory overall.                                 | Code documentation is only partially there. Writing has some usage errors, some poor fluency, or some poor rhetoric. If doc/writing are both like this you get developing. If one is developing and the other is satisfactory you still get developing.                                                                             | Code is documented throughout. Writing has good fluency, good rhetoric, and at most a few minor errors.                                                                                                                                                       | Code documentation is highly informative with docstrings. Writing is high quality. If both doc/writing are like this you get excellent. If one is satisfactory and the other excellent you still get satisfactory.                                                                                                                                                |
# | Video (developing -1.5 points, unsatisfactory -3 points)                           | Video well outside the 3–5 min time range. Does not communicate major results at a non-technical level. Has major technical issues such as no sound or not available at link. Unsatisfactory if 2/3 of these are true.                                                                             | Video just outside the 3–5 min time range. Does not communicate well on some points (either wrong tech level or just confusing). Has technical issues such as poor speech quality on video. Developing if 2/3 of these are true.                                                                                                   | Video has good quality and is within 3–5 min range. Communicates the major results at an accessible level for non-technical people.                                                                                                                           | Video has high production quality and is within 3–5 min range. Communicates the major results clearly and gives a sense of the methods at an accessible level for non-technical people. Has a wow factor (e.g. funny or original approach).                                                                                                                     |
# | Quality modifier (can result in extra credit beyond 18 points for this assignment) | Almost everything was just barely proficient. Lots of minimal effort work. Do not double punish; if they already lost points on the rubric do not invoke this: -0.5 points.                                                                                                                        |                                                                                                                                                                                                                                                                                                                                     |                                                                                                                                                                                                                                                               | More than 5 excellents on this rubric: +0.5 points.                                                                                                                                                                                                                                                                                                                |

# %% [markdown]
# # COGS 108 - Final Project (change this to your project's title)

# %% [markdown]
# ## Permissions (Not Complete)
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video (Not Complete)
# https://link.to.your.publicly.viewable.video
#
# ## Abstract (Not Complete)
# |
# Please write one to four paragraphs that describe a very brief overview of why you did this, how you did, and the major findings and conclusions.

# %% [markdown]
# ## Authors (Not Updated)
#
# - Aryaman Dayal: Writing - original draft (Dataset search, Methodology and Metric Inspection, Academic-level-stratified analysis)
# - Dhruv Sehgal: Writing - original draft (Ethics, Team Expectations, scatter + regression)
# - Prachi Heda: Writing - original draft (Background and Prior Work, Data overview, distribution analysis, correlation analysis, Gender-stratified analysis, Data Analysis Slides and Conclusion Slides)
# - Ricky Zhang: Writing - original draft (Research question, Hypothesis, Outlier and Missingness Inspection, Competing Explanatory Variables exploration)
# - Kaylee Viriyavong: Writing - original draft (Project timeline proposal, summary statistics for variables, Interaction exploration)

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your proposal feedback

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Mental health concerns among college students have increased in recent years, with rising reports of anxiety and depression, coupled with the growth of social media platforms. Because most students engage with social networking sites daily, researchers have become interested in understanding whether online behavior plays a role in psychological well-being. While early discussions often focused on the amount of time spent online, more recent work has shifted toward examining the quality and consequences of social media use, including whether the behavior is compulsive, causes interpersonal conflict, or interferes with daily life.
#
#
# Social media use is extremely common among college students, but researchers now separate how much people use social platforms (time or frequency) from how they use them (such as compulsive or conflict-driven behavior). “Problematic social media use,” also described as social media addiction, refers to patterns that are hard to control and that disrupt daily life.<a name="cite_ref-1"></a><sup>1</sup> This distinction matters for our project because the dataset includes both an addiction-like score and relationship-focused variables, such as conflicts. This lets us examine whether problematic use is linked to worse mental health outcomes beyond what can be explained by time spent on social media alone.
#
#
# Prior research consistently shows that higher levels of problematic social media use are linked to poorer mental health outcomes, including higher depression and anxiety symptoms and lower overall well-being.<a name="cite_ref-2"></a><sup>2</sup><a name="cite_ref-3"></a><sup>3</sup> However, many studies emphasize that causality is unclear and that these effects may depend on individual or social factors. One systematic review of adolescents and young adults found widespread links between problematic use and depression and stress, but noted that most studies were cross-sectional and therefore could not determine whether social media use leads to poorer mental health or vice versa.<a name="cite_ref-2"></a><sup>2</sup> Public health reports argue that risks cannot be captured by screen time alone and that the type of engagement and harmful experiences matter more than total time spent online.<a name="cite_ref-4"></a><sup>4</sup> These findings motivate two directions for our study: first, testing whether addiction-like measures of social media use are associated with mental health and whether that association varies by gender or academic level, and second, examining whether conflict-related experiences predict poorer mental health even after controlling for total usage time and relationship status.
#
#
# Measurement research is also relevant to our analysis. Many studies assess problematic social media use using validated tools such as the Bergen Social Media Addiction Scale (BSMAS), which is based on core addiction features like salience, mood modification, tolerance, withdrawal, conflict, and relapse.<a name="cite_ref-1"></a><sup>1</sup> Validation studies show that the BSMAS has a stable structure and can reliably measure problematic use in young populations, making it useful for studying links with mental health and related outcomes.<a name="cite_ref-1"></a><sup>1</sup> Although our Kaggle dataset uses its own addiction score, this work helps clarify what this measure is intended to capture.
#
#
# Because one potential research direction focuses specifically on interpersonal conflict and relationship factors, earlier work on romantic and social relationships is especially relevant. Studies of college students and young adults have found that heavier social media use is associated with relationship strain.<a name="cite_ref-5"></a><sup>5</sup><a name="cite_ref-6"></a><sup>6</sup> In particular, Clayton et al. reported that greater Facebook use was linked to worse relationship outcomes especially in newer relationships.<a name="cite_ref-5"></a><sup>5</sup> Other research on “Facebook intrusion” reported similar connections between intrusive use, jealousy, and reduced satisfaction in undergraduate romantic relationships.<a name="cite_ref-6"></a><sup>6</sup> These results support our plan to examine whether conflicts over social media predict lower mental health scores, even after accounting for usage time and relationship status.
#
#
# Finally, prior studies suggest that the relationship between problematic technology use and well-being can differ across demographic groups, which motivates our future analyses by gender and academic level. Research on smartphone addiction among undergraduates, for example, has reported gender differences in prevalence and associated factors, implying that risks and outcomes may not be the same for everyone.<a name="cite_ref-7"></a><sup>7</sup> Therefore, one possible research question for this study is whether the association between social media addiction scores and mental health differs by gender or academic level, rather than assuming a single overall effect for all students.
#
# ### References
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1)
# Lin, C.-Y., Broström, A., Nilsen, P., Griffiths, M. D., & Pakpour, A. H. (2017). *Psychometric validation of the Persian Bergen Social Media Addiction Scale (BSMAS).* Addiction Research & Theory.
# https://pmc.ncbi.nlm.nih.gov/articles/PMC6034942/
#
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2)
# Shannon, H., Bush, K., Villeneuve, P. J., Hellemans, K. G. C., & Hartling, L. (2022). *Problematic Social Media Use in Adolescents and Young Adults: Systematic Review and Meta-analysis.* JMIR Mental Health.
# https://mental.jmir.org/2022/4/e33450/
#
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3)
# Ahmed, O., et al. (2024). *Social media use, mental health and sleep: A systematic review.* Journal of Affective Disorders.
# https://www.sciencedirect.com/science/article/pii/S0165032724014265
#
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4)
# U.S. Surgeon General. (2023). *Social Media and Youth Mental Health: The U.S. Surgeon General’s Advisory.*
# https://www.hhs.gov/sites/default/files/sg-youth-mental-health-social-media-advisory.pdf
#
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5)
# Clayton, R. B., Nagurney, A., & Smith, J. R. (2013). *Cheating, breakup, and divorce: Is Facebook use to blame?* Cyberpsychology, Behavior, and Social Networking.
# https://journals.sagepub.com/doi/full/10.1089/cyber.2012.0424
#
# 6. <a name="cite_note-6"></a> [^](#cite_ref-6)
# Elphinston, R. A., & Noller, P. (2011). *Time to face it! Facebook intrusion and the implications for romantic jealousy and relationship satisfaction.* Cyberpsychology, Behavior, and Social Networking.
# https://pubmed.ncbi.nlm.nih.gov/21548798/
#
# 7. <a name="cite_note-7"></a> [^](#cite_ref-7)
# Chen, B., Liu, F., Ding, S., Ying, X., Wang, L., & Wen, Y. (2017). *Gender differences in factors associated with smartphone addiction: a cross-sectional study among medical college students.* BMC Psychiatry.
# https://pmc.ncbi.nlm.nih.gov/articles/PMC5634822/

# %% [markdown]
# ## Research Question

# %% [markdown]
# For this project, our interest is to answer the following question:
#
# Is there, for students, a statistically significant relationship between social media addiction score and mental health score, and does this relationship differ by gender or academic level?
#
# For context, we will define the social media addiction score and mental health score as the following:
# * Social Media Addiction Score: a self-reported single-item measure on a 10-point Likert scale, where:
#     *  1 = Very poor mental health (frequent distress, anxiety, low mood, difficulty coping)
#     *  10 = Excellent mental health (emotionally stable, low stress, positive mood, good coping ability)
# * Mental Health Score: a self-reported 10-point Likert scale measure, where:
#     *  1 = No signs of addictive behavior (controlled, balanced use)
#     *  10 = Severe addictive tendencies (compulsive use, inability to reduce usage, interference with sleep, academics, or relationships)

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict that there is a statistically significant relationship between social media addiction and mental health score for university students, clearly differing by gender and academic level. In fact, several signs of bad mental health such as detachment of reality and excess fear or worry are commly attributed to the growing and prevasive social media algorithms. When considering the influence of targeted post against users of certain academic level and promoted gender conformity, it is not surprising for intersectionality to exist  between these set of elements.

# %% [markdown]
# ## Data

# %% [markdown]
# **Ideal Dataset:**
# To answer whether social media addiction is related to mental health and whether that relationship differs by gender or academic level, the ideal dataset for our project would be student-level survey data that includes a validated measure of social media addiction, a validated measure of mental health, demographic information on gender, and a clear indicator of academic level such as year in school or undergraduate versus graduate status. We would also want a few important background variables that could affect both social media use and mental health, such as age, typical daily time spent on social media, sleep habits, and basic school or location context so we can account for major differences across groups. In terms of sample size, we need enough students in each gender and academic-level group to reliably detect differences in the relationship, so several hundred students at minimum and ideally closer to one thousand or more is a strong target, especially if group sizes are uneven. These data would ideally be collected through a standardized survey distributed across multiple schools or through stratified sampling to ensure representation across genders and academic levels, using consistent scoring procedures and a documented codebook. We would store the data in a clean, organized table where each row represents one student and each column represents one variable, with clear variable definitions, consistent handling of missing values, and documentation explaining how the addiction and mental health scores were computed and interpreted.
#
# **Dataset 1 ([Link 1](https://www.kaggle.com/datasets/adilshamim8/social-media-addiction-vs-relationships)):**
# This dataset is hosted on Kaggle under the title “Students’ Social Media Addiction,” and we would need a Kaggle account to accept the dataset’s terms and download the CSV file for analysis. It includes variables that map directly onto our research question, including an addiction score, a mental health score, gender, and academic level, along with related factors like average daily usage, sleep per night, and other context variables such as platform, relationship status, and social media conflicts. Using this dataset, we could model mental health as a function of addiction and then test whether the strength of that relationship changes across gender and academic level, while optionally controlling for usage and sleep. This makes it a strong match for the full set of analyses we want to run.
#
# **Dataset 2 ([Link 2](https://www.kaggle.com/datasets/zahranusratt/student-social-media-addiction-analysis-dataset)):**
# This Kaggle dataset also provides a CSV titled “Students Social Media Addiction.csv,” and we would similarly need Kaggle access and to download the file before we can use it. Public writeups and analyses of this same CSV indicate it contains about 705 rows and 13 columns, and the core fields include gender, academic level, mental health score, and addiction score, plus usage and lifestyle variables such as daily usage and sleep. Functionally, it supports the same main tests we want, including estimating the overall relationship between addiction and mental health and checking whether that relationship differs across subgroups. It is also useful for comparing our results against existing Kaggle notebooks or replications that use the same file structure.

# %% [markdown]
# After careful review, we decided to use the first dataset described above. Below are the preliminary findings of the dataset.

# %%
# Run this code every time when you're actively developing modules in .py files.  It's not needed if you aren't making modules
#
## this code is necessary for making sure that any modules we load are updated here 
## when their source code .py files are modified

# %load_ext autoreload
# %autoreload 2

# %%
# %pip install requests tqdm
# %pip install pandas

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

# Might need to nove these to ,.modules?
import pandas as pd 
import numpy as np
from pathlib import Path
import get_data
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from IPython.display import display
import seaborn as sns
import statsmodels.formula.api as smf


datafiles = [
    { 'url': 'https://drive.google.com/uc?export=download&id=1OOzFA2-e2j92c0HMrKnJ2z3HTr_oFZmg', 'filename':'Students Social Media Addiction.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Overall Download Progress: 100%|██████████| 1/1 [00:01<00:00,  1.27s/it]
# Successfully downloaded: Students Social Media Addiction.csv

# %% [markdown]
# ### Selected Dataset: Students' Social Media Addiction
#
#   - **Link to the dataset**: https://www.kaggle.com/datasets/adilshamim8/social-media-addiction-vs-relationships
#   - **Number of observations**: 705
#   - **Number of variables**: 13
#   - **Description of the variables most relevant to this project**
#     - **Academic_Level**: _Categorical_, High School / Undergraduate / Graduate
#     - **Gender**:	_Categorical_,	“Male” or “Female”
#     - **Avg_Daily_Usage_Hours**:	_Float_,	Average hours per day on social media
#     - **Most_Used_Platform**:	_Categorical_,	Instagram, Facebook, TikTok, etc.
#     - **Mental_Health_Score**:	_Integer_,	Self‐rated mental health (1 = poor to 10 = excellent)
#     - **Conflicts_Over_Social_Media**:	_Integer_,	Number of relationship conflicts due to social media
#     - **Addicted_Score**:	_Integer_,	Social Media Addiction Score (1 = low to 10 = high)
#   - **Shortcomings**
#     - **Self‐Report Bias**: All measures are self‐reported and may be subject to social‐desirability effects.
#     - **Cross‐Sectional Design**: One‐time survey prevents causal inference.
#     - **Sampling Variability**: Recruitment via online channels may underrepresent students with limited internet access.
#     - **Spurious Associations**: No socioeconomic status proxies (income, parental education), no academic performance metric (GPA/grades)

# %% [markdown]
# This dataset is a cross sectional student survey with 705 responses and 13 variables that describe demographics, daily social media habits, sleep, mental health ratings, academics, and relationship conflict tied to social media. Each row corresponds to one student, and Student_ID appears to be an anonymized identifier rather than personally identifying information. The respondents are mostly in the late teen to young adult range, roughly ages 16 to 25, so the dataset is best interpreted as a snapshot of student experiences rather than a general population sample.
#
# There are a few major concerns to keep in mind. First, nearly all variables are self reported, so usage hours, sleep, mental health, and addiction severity can be affected by memory errors and by how comfortable someone is reporting honestly. Second, the data are cross sectional, meaning they capture one point in time, so you can study associations but you cannot say social media use causes changes in mental health, sleep, or relationship conflict. Third, the sample is likely shaped by who chose to respond, so it may not be representative of all students, and responses across countries can differ based on culture and how people interpret rating scales. Finally, some public writeups describe the score ranges slightly differently, so it is safer to verify the actual distributions directly in the dataset before using strict cutoffs or treating the scales as standardized clinical measures.

# %% [markdown]
# #### Data Cleaning and Wrangling

# %%
ssma = pd.read_csv('data/00-raw/Students Social Media Addiction.csv')
ssma
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 1             2   22    Male       Graduate       India
# 2             3   20  Female  Undergraduate         USA
# 3             4   18    Male    High School          UK
# 4             5   21    Male       Graduate      Canada
# ..          ...  ...     ...            ...         ...
# 700         701   20  Female  Undergraduate       Italy
# 701         702   23    Male       Graduate      Russia
# 702         703   21  Female  Undergraduate       China
# 703         704   24    Male       Graduate       Japan
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 1                      2.1            Twitter                           No
# ...

# %%
print(f"There is a total of {ssma.shape[0]} observation and {ssma.shape[1]} variables.")
# Out:
# There is a total of 705 observation and 13 variables.

# %%
ssma.dtypes
# Out:
# Student_ID                        int64
# Age                               int64
# Gender                           object
# Academic_Level                   object
# Country                          object
# Avg_Daily_Usage_Hours           float64
# Most_Used_Platform               object
# Affects_Academic_Performance     object
# Sleep_Hours_Per_Night           float64
# Mental_Health_Score               int64
# Relationship_Status              object
# Conflicts_Over_Social_Media       int64
# Addicted_Score                    int64
# dtype: object

# %%
# Tidiness and outlier Inspection

print("====================== Variable Inspection =============================")
print(f"\nStudent_ID should be unique and we can prove by inspecting the total uniqueness count:")
print(f"  The student ID count is {ssma.shape[0]}, while unique student id count is {ssma.Student_ID.nunique()}. The count {'matches' if ssma.shape[0] == ssma.Student_ID.nunique() else 'does not match'}.\n")

print("Age should be reasonable and numeric, such as the range of 1 to 100 (Although the age are usually betweeen 18 and 24).")
print(f"  The age ranges between {ssma.Age.min()} and {ssma.Age.max()}, which is what we expect.")
print(f"  Unique ages are: {ssma.Age.unique()}.\n")

print("Gender should be categorical.")
print(f" Unique genders are: {ssma.Gender.unique()}.")
print(f"All genders are expected and no outliers are spotted.\n")

print("Country should also be categorical.")
print(f" Unique countries are: {ssma.Country.unique()}")
print(f" While formatting is slightly inconsistent (e.g., USA vs full names), no obvious typographical errors were detected.\n")

print("Avg_Daily_Usage_Hours should be numerical, nonnegative, and reasonable (below 24 hours).")
print(f" There are {ssma.query('Avg_Daily_Usage_Hours >= 0 & Avg_Daily_Usage_Hours <= 24').shape[0]} entries that match our expectation defined above, which matches the total number observations.")
print(f" By the code confirmation I done, it also ensures that every entry is numerical as otherwise, it would yield error before it could display the result.")
print(f" The Avg_Daily_Usage_Hours ranges between {ssma.Avg_Daily_Usage_Hours.min()} and {ssma.Avg_Daily_Usage_Hours.max()}, which is reasonable.\n")

print("Most_Used_Platform should be strings and no typos should exist.")
print(f" Unique platforms are: {ssma.Most_Used_Platform.unique()}.")
print(f" No observations are out of ordinary as shown above.\n")

print("Affects_Academic_Performance should be binary (Yes or No).")
print(f" Unique responses to Affects_Academic_Performance are: {ssma.Affects_Academic_Performance.unique()}.")
print(f" As expected and shown above, only two response exists.\n")

print("Sleep_Hours_Per_Night should be numerical, nonnegative, and reasonable (below 24 hours).")
print(f" There are {ssma.query('Sleep_Hours_Per_Night >= 0 & Sleep_Hours_Per_Night <= 24').shape[0]} entries that match our expectation defined above, which matches the total number observations.")
print(f" By the code confirmation I done, it also ensures that every entry is numerical as otherwise, it would yield error before it could display the result.")
print(f" The Sleep_Hours_Per_Night ranges between {ssma.Sleep_Hours_Per_Night.min()} and {ssma.Sleep_Hours_Per_Night.max()}, which is reasonable.\n")

print("Mental_Health_Score should be between 1 and 10 and numerical.")
print(f" There are {ssma.query('Mental_Health_Score >= 1 & Mental_Health_Score <= 10').shape[0]} entries that match our expectation defined above, which matches the total number observations.")
print(f" By the code confirmation I done, it also ensures that every entry is numerical as otherwise, it would yield error before it could display the result.\n")

print("Relationship_Status should be categorical.")
print(f" Unique countries are: {ssma.Relationship_Status.unique()}")
print(f" We see three variations which are distinct and clear.\n")

print("Conflicts_Over_Social_Media should be numerical (count), nonnegative.")
print(f" There are {ssma.query('Conflicts_Over_Social_Media >= 0').shape[0]} entries that match our expectation defined above, which matches the total number observations.")
print(f" The Conflicts_Over_Social_Media ranges between {ssma.Conflicts_Over_Social_Media.min()} and {ssma.Conflicts_Over_Social_Media.max()}, which is reasonable.\n")

print("Addicted_Score should be between 1 and 10 and numerical.")
print(f" There are {ssma.query('Addicted_Score >= 1 & Addicted_Score <= 10').shape[0]} entries that match our expectation defined above, which matches the total number observations.")
print(f" By the code confirmation I done, it also ensures that every entry is numerical as otherwise, it would yield error before it could display the result.\n")
# Out:
# ====================== Variable Inspection =============================
#
# Student_ID should be unique and we can prove by inspecting the total uniqueness count:
#   The student ID count is 705, while unique student id count is 705. The count matches.
#
# Age should be reasonable and numeric, such as the range of 1 to 100 (Although the age are usually betweeen 18 and 24).
#   The age ranges between 18 and 24, which is what we expect.
#   Unique ages are: [19 22 20 18 21 23 24].
#
# Gender should be categorical.
#  Unique genders are: ['Female' 'Male'].
# All genders are expected and no outliers are spotted.
#
# Country should also be categorical.
#  Unique countries are: ['Bangladesh' 'India' 'USA' 'UK' 'Canada' 'Australia' 'Germany' 'Brazil'
#  'Japan' 'South Korea' 'France' 'Spain' 'Italy' 'Mexico' 'Russia' 'China'
#  'Sweden' 'Norway' 'Denmark' 'Netherlands' 'Belgium' 'Switzerland'
#  'Austria' 'Portugal' 'Greece' 'Ireland' 'New Zealand' 'Singapore'
# ...

# %% [markdown]
# By the above unique outputs, we can clearly determine that each row is an observation, each column is a variable, and each cell is a single value. Otherwise we would see cells with values that seem to be of multiple response, such as 'India, USA'. In addition, there are no duplicate entries as each row corresponds to an unique student_ID. The format is consistent too as inspected and no extraneous characters are found. Furthermore, no missing entries are found as we will show below. Thus, we can conclude the data is tidy.
#
# On a separate note, through the inspection of unique values, we see now suspicious entries or outliers considering the type of question and mentioned demographic discussed in the source website description.
#
# Finally, because there are no missing values, no imputation or row deletion was required.

# %%
# Missinginess Inspection
print(f"The variables for each observation is {'all present' if ssma.isna().sum().sum() == 0 else 'missing for some'}.\n")
print("The following output describes the missingness for each variable. 0 represents no missing value, while 1 represents the presence of missing value.")
print(ssma.isna().sum())

print(f"\nSince there are no missing values, the missingness mechanisms are not applicable in this dataset.")
# Out:
# The variables for each observation is all present.
#
# The following output describes the missingness for each variable. 0 represents no missing value, while 1 represents the presence of missing value.
# Student_ID                      0
# Age                             0
# Gender                          0
# Academic_Level                  0
# Country                         0
# Avg_Daily_Usage_Hours           0
# Most_Used_Platform              0
# Affects_Academic_Performance    0
# Sleep_Hours_Per_Night           0
# Mental_Health_Score             0
# Relationship_Status             0
# Conflicts_Over_Social_Media     0
# Addicted_Score                  0
# dtype: int64
#
# Since there are no missing values, the missingness mechanisms are not applicable in this dataset.

# %%
ssma.to_csv("data/02-processed/Students Social Media Addiction_clean.csv", index=False)

# %% [markdown]
# #### Summary Statistics for Key Variables
#
# For this project, the most important variables relate to:

# %% [markdown]
# **Addiction Score**
#
# The mean social media addiction score is approximately 6.4, with values generally ranging from 2 to 9. Higher scores indicate stronger signs of addictive social media behavior, such as compulsive use, difficulty limiting usage, or interference with daily activities. From our observation (see EDA), the distribution appears moderately centered around the middle of the scale, suggesting that most students report moderate levels of social media dependence rather than extremely low or extremely high addiction levels.
#
# **Mental Health Score**
#
# The mean mental health score is approximately 6.2, with values ranging from 4 to 9. Lower scores correspond to poorer mental health and higher scores represent stronger emotional well-being. From our observation (see EDA), mental health scores vary within a moderate range, indicating variability in perceived well-being among students.
#
# **Gender**
#
# Gender is sampled equally between male and female students, 700 students total.
#
# **Academic Level**
#
# Most participants of the study are undergraduates and graduates. Only around 30 participants were high schoolers.
#
# ##### Why These Variables Are Important
#
# Addiction Score functions as the primary explanatory variable, representing the degree to which students exhibit problematic social media usage.
#
# Mental Health Score serves as the primary outcome variable, capturing students’ self-reported psychological well-being.
#
# Gender provides demographic context and allows us to examine whether the relationship between addiction and mental health differs across groups.
#
# Academic Level provides additional context regarding students’ academic stage and allows us to investigate whether the relationship between social media addiction and mental health varies across different educational levels.
#
# Together, these variables directly relate to our research question examining whether there is a statistically significant relationship between social media addiction and mental health among students, and whether that relationship differs by gender or academic level.

# %% [markdown]
# ## Results

# %% [markdown]
# ### Exploratory Data Analysis
#
# **NOTE** The final report should not be overly long.  If this EDA step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any EDA you later decided was unecessary side quest.
# 2) if the code to EDA is very long (in either lines or in time to compute) make sure you write out images of the EDA into `results/` and reload them as images here instead of recalculating it. And make a statement here like "To see the code responsible for EDA analyses see `02-EDACheckpoint.ipynb`."

# %% [markdown]
# #### EDA: Distribution Analysis
#
# This section  aims to understand the basic structure and behavior of each relevant variable in the dataset before analyzing relationships between variables

# %% [markdown]
# ##### Basic dataset characteristics

# %%
ssma = pd.read_csv('data/02-processed/Students Social Media Addiction_clean.csv')

print("Rows, cols:", ssma.shape)
print("\nMissing values per column:\n", ssma.isna().sum().sort_values(ascending=False))
print("\nUnique counts:\n", ssma.nunique().sort_values(ascending=False))
# Out:
# Rows, cols: (705, 13)
#
# Missing values per column:
#  Student_ID                      0
# Age                             0
# Gender                          0
# Academic_Level                  0
# Country                         0
# Avg_Daily_Usage_Hours           0
# Most_Used_Platform              0
# Affects_Academic_Performance    0
# Sleep_Hours_Per_Night           0
# Mental_Health_Score             0
# Relationship_Status             0
# Conflicts_Over_Social_Media     0
# Addicted_Score                  0
# dtype: int64
#
# Unique counts:
#  Student_ID                      705
# Country                         110
# Avg_Daily_Usage_Hours            67
# Sleep_Hours_Per_Night            59
# Most_Used_Platform               12
# Addicted_Score                    8
# Age                               7
# Mental_Health_Score               6
# Conflicts_Over_Social_Media       6
# Academic_Level                    3
# Relationship_Status               3
# ...

# %% [markdown]
# Interpretation
# - Dataset contains 705 students and all columns are complete
#
# - Key grouping variables (Gender, Academic_Level) have limited categories and are suitable for stratified analyses
#
# - Some fields (Country) have many levels, so later visualizations can use top-N aggregation

# %% [markdown]
# ##### Numeric distributions
#
# Variables to treat as numeric:
# - Addicted_Score (main predictor)
# - Mental_Health_Score (main outcome)
# - Avg_Daily_Usage_Hours
# - Sleep_Hours_Per_Night
# - Conflicts_Over_Social_Media
# - Age

# %%
num_cols = [
    "Age","Avg_Daily_Usage_Hours","Sleep_Hours_Per_Night",
    "Mental_Health_Score","Conflicts_Over_Social_Media","Addicted_Score"
]

summary = ssma[num_cols].describe(percentiles=[.05,.25,.5,.75,.95]).T
summary["skew"] = ssma[num_cols].skew(numeric_only=True)
summary["kurtosis"] = ssma[num_cols].kurtosis(numeric_only=True)
summary
# Out:
#                              count       mean       std   min     5%   25%  \
# Age                          705.0  20.659574  1.399217  18.0  19.00  19.0
# Avg_Daily_Usage_Hours        705.0   4.918723  1.257395   1.5   2.82   4.1
# Sleep_Hours_Per_Night        705.0   6.868936  1.126848   3.8   5.02   6.0
# Mental_Health_Score          705.0   6.226950  1.105055   4.0   5.00   5.0
# Conflicts_Over_Social_Media  705.0   2.849645  0.957968   0.0   1.00   2.0
# Addicted_Score               705.0   6.436879  1.587165   2.0   4.00   5.0
#
#                               50%   75%   95%   max      skew  kurtosis
# Age                          21.0  22.0  23.0  24.0  0.368909 -0.507844
# Avg_Daily_Usage_Hours         4.8   5.8   7.0   8.5  0.164634 -0.352554
# Sleep_Hours_Per_Night         6.9   7.7   8.6   9.6 -0.109040 -0.519811
# Mental_Health_Score           6.0   7.0   8.0   9.0  0.049023 -0.835574
# Conflicts_Over_Social_Media   3.0   4.0   4.0   5.0 -0.162340 -0.383374
# ...

# %% [markdown]
# Interpretation:
# - Age ranges from 18 to 24, with a mean of 20.66 and low standard deviation showing the sample is concentrated around typical college-aged students
# - Average daily social media usage ranges from 1.5 to 8.5 hours, with a mean of 4.92 hours suggesting moderate variability in usage intensity
# - Sleep hours per night average 6.87 hours (range 3.8–9.6), indicating some students experience relatively low sleep levels
# - Mental health scores range from 4 to 9, with a mean of 6.23 and median of 6, suggesting most students report moderate mental health levels with reasonable spread
# - Social media addiction scores range from 2 to 9, with a mean of 6.44, indicating that many students report moderately high levels of social media addiction.
# - Skewness values for all variables are close to zero, suggesting approximately symmetric distributions, and kurtosis values are slightly negative, indicating light-tailed distributions without extreme outliers

# %% [markdown]
# ##### Histograms

# %%
plots = [
    ("Addicted_Score", "Addicted Score", np.arange(1.5, 10.5, 1)),            # bins centered on integers 2..10
    ("Mental_Health_Score", "Mental Health Score", np.arange(0.5, 10.5, 1)),  # bins centered on integers 1..10
    ("Avg_Daily_Usage_Hours", "Avg Daily Usage (Hours)", 10),                 # continuous
    ("Sleep_Hours_Per_Night", "Sleep Hours Per Night", 10),                   # continuous
    ("Conflicts_Over_Social_Media", "Conflicts Over Social Media", np.arange(-0.5, 6.5, 1)),  # 0..5
]

fig, axes = plt.subplots(2, 3, figsize=(12, 8), sharey=True)
axes = axes.flatten()

for i, (col, title, bins) in enumerate(plots):
    axes[i].hist(ssma[col].dropna(), bins=bins)
    axes[i].set_title(title, fontsize=11)
    axes[i].set_xlabel(title, fontsize=10)
    axes[i].set_ylabel("Count", fontsize=10)
    axes[i].grid(True, axis="y", alpha=0.3)

# Remove empty last subplot for a clean 2x3 layout
fig.delaxes(axes[-1])

fig.suptitle("Distributions of Key Numeric Variables", fontsize=14)
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# Interpretation:
# - Addicted_Score and Mental_Health_Score both show moderate spread indicating sufficient variability to analyze their relationship
# - Average daily social media usage centers around 4–6 hours, suggesting many students engage heavily with social media.
# - Sleep hours cluster around 6–8 hours, with some lower values that could relate to higher social media use or poorer mental health.
# - Overall the distributions show reasonable variation across key variables, supporting further analysis of the relationship between social media addiction and mental health, and whether it differs by gender or academic level.

# %% [markdown]
# ##### Boxplots

# %%
cols = [
    "Addicted_Score",
    "Mental_Health_Score",
    "Avg_Daily_Usage_Hours",
    "Sleep_Hours_Per_Night",
    "Conflicts_Over_Social_Media"
]

titles = [
    "Addicted Score",
    "Mental Health Score",
    "Avg Daily Usage (Hours)",
    "Sleep Hours Per Night",
    "Conflicts Over Social Media"
]

fig, axes = plt.subplots(2, 3, figsize=(12, 8), sharey=False)
axes = axes.flatten()

for i, col in enumerate(cols):
    axes[i].boxplot(ssma[col].dropna(), vert=True)
    axes[i].set_title(titles[i], fontsize=11)
    axes[i].set_ylabel(titles[i])
    axes[i].set_xticks([])
    axes[i].grid(True, axis="y", alpha=0.3)

# remove empty subplot
fig.delaxes(axes[-1])

fig.suptitle("Boxplots of Key Numeric Variables", fontsize=14)
plt.tight_layout(rect=[0,0,1,0.95])
plt.show()

# %% [markdown]
# Interpretation:
# - there are a few outliers in Avg_Daily_Usage_Hours, showing that some students spend unusually high or low amounts of time on social media compared to the rest
# - The boxplots appear relatively balanced around the median for most variables suggesting no strong skew or extreme imbalance

# %% [markdown]
# ##### Categorical Distributions
#
# Variables to treat as categorical:
# - Gender
# - Academic_Level
# - Affects_Academic_Performance
# - Most_Used_Platform
# - Relationship_Status
# - Country

# %% [markdown]
# ##### Frequency and proportion tables

# %%
cat_cols = [
    "Gender",
    "Academic_Level",
    "Affects_Academic_Performance",
    "Relationship_Status",
    "Most_Used_Platform"
]

fig, axes = plt.subplots(2, 3, figsize=(12, 8))
axes = axes.flatten()

for i, col in enumerate(cat_cols):
    
    counts = ssma[col].value_counts()
    
    # limit platforms so the chart stays readable
    if col == "Most_Used_Platform":
        counts = counts.head(8)
    
    axes[i].bar(counts.index.astype(str), counts.values)
    axes[i].set_title(cat_cols[i], fontsize=11)
    axes[i].set_ylabel("Count")
    axes[i].tick_params(axis='x', rotation=45)
    axes[i].grid(True, axis="y", alpha=0.3)

# remove empty subplot
fig.delaxes(axes[-1])

fig.suptitle("Distributions of Key Categorical Variables", fontsize=14)
plt.tight_layout(rect=[0,0,1,0.95])
plt.show()

# %% [markdown]
# Interpretation:
# - Gender: The sample is balanced between male and female students
# - Academic Level: Most respondents are undergraduate or graduate students
# - Academic Impact: A majority report that social media affects their academic performance
# - Relationship Status: Most students are single, with fewer in relationships or complicated statuses
# - Platforms: Instagram and TikTok are the most commonly used platforms
# - Country: The dataset is international, with the most respondents from India, the USA, and Canada

# %%
country_counts = ssma["Country"].value_counts().head(10)

plt.figure(figsize=(8,5))
plt.bar(country_counts.index.astype(str), country_counts.values)
plt.title("Top 10 Countries in Dataset")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.grid(True, axis="y", alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### EDA: Scatter Plot and Regression Analysis
#
# In this section, we explore the relationship between `Addicted_Score` and `Mental_Health_Score`. We want to see whether the relationship is suitable for regression.

# %%
x = ssma['Addicted_Score']
y = ssma['Mental_Health_Score']

# Fit regression line
m, b = np.polyfit(x, y, 1)

plt.figure()

plt.scatter(x, y, alpha=0.5)
plt.plot(x, m*x + b, 'red')

plt.xlabel("Addicted Score")
plt.ylabel("Mental Health Score")
plt.title("Addicted Score vs Mental Health Score")

plt.show()

# %%
x = ssma['Addicted_Score']
y = ssma['Mental_Health_Score']

# Fit regression line
m, b = np.polyfit(x, y, 1)

# Predicted values
y_pred = m * x + b

plt.figure()

# Scatter points
plt.scatter(x, y, alpha=0.5)

# Regression line
plt.plot(x, y_pred, 'red')

# Residual lines (distance to regression line)
for xi, yi, yhat in zip(x, y, y_pred):
    plt.plot([xi, xi], [yi, yhat], linewidth=0.8)

plt.xlabel("Addicted Score")
plt.ylabel("Mental Health Score")
plt.title("Residual Distances from Regression Line")

plt.show()

# %%
plt.figure()

residuals = y - y_pred
plt.scatter(x, residuals, alpha=0.5)
plt.axhline(0, color='red')

plt.xlabel("Addicted Score")
plt.ylabel("Residuals")
plt.title("Residual Plot: Addicted Score vs Mental Health Score")

plt.show()

# %% [markdown]
# **Interpretation**
#
# * Mental Health Score and Addicted Score are negatively correlated. This means that as students report higher addicted scores, their self-reported mental health scores tend to go down.
#
#   * Put simply, the chart above shows that students say their mental health gets worse as they use social media more.
#
# * While there is some correlation, the relationship is approximately linear, suggesting a linear model could be appropriate for further analysis. This is further shown by the regression line plotted, which follows along with the data points quite well.
#
# * Looking at the residual plots, since the residuals seem to be scattered around 0 randomly, the variance of residuals appears to be constant for the overall relationship. Therefore, the assumption of heteroscedasticity for a linear model to be valid should hold.

# %% [markdown]
# #### EDA: Correlation Analysis
#
# To examine whether social media addiction is associated with mental health among students, we computed the Pearson correlation coefficient between `Addicted_Score` and `Mental_Health_Score`.
#
# Since both variables are numerical and measured on a 1–10 scale, Pearson correlation is an appropriate method for measuring the linear relationship between two continuous variables.

# %%
ssma[['Addicted_Score','Mental_Health_Score']].corr()
# Out:
#                      Addicted_Score  Mental_Health_Score
# Addicted_Score             1.000000            -0.945051
# Mental_Health_Score       -0.945051             1.000000

# %%
from scipy.stats import pearsonr

r, p = pearsonr(ssma['Addicted_Score'], ssma['Mental_Health_Score'])

print("Correlation coefficient:", r)
print("p-value:", p)
# Out:
# Correlation coefficient: -0.9450506757277405
# p-value: 0.0

# %% [markdown]
# Interpretation:
# - The Pearson correlation coefficient of r = -0.945 indicates a very strong negative relationship between social media addiction score and mental health score
#   - This means that as students’ addiction scores increase, their mental health scores tend to decrease
# - The p-value is less than 0.001, indicating that this relationship is statistically significant and extremely unlikely to have occurred by random chance
# - These results suggest that there is a strong and statistically significant relationship between social media addiction and mental health among students

# %% [markdown]
# #### EDA: Academic-Level Stratified Analysis
#
# This section focuses on the relationship between `Addicted_Score` and `Mental_Health_Score`, stratified by `Academic_Level`.

# %%
level_order = ['High School', 'Undergraduate', 'Graduate']
analysis_df = ssma[['Academic_Level', 'Addicted_Score', 'Mental_Health_Score']].dropna().copy()
analysis_df['Academic_Level'] = pd.Categorical(
    analysis_df['Academic_Level'], categories=level_order, ordered=True
)

stratified_stats = (
    analysis_df.groupby('Academic_Level', observed=False)
    .agg(
        n=('Addicted_Score', 'size'),
        pearson_r=('Addicted_Score', lambda x: x.corr(analysis_df.loc[x.index, 'Mental_Health_Score'])),
        median_addicted_score=('Addicted_Score', 'median'),
        median_mental_health_score=('Mental_Health_Score', 'median')
    )
    .round(3)
)

display(stratified_stats)

sns.set_theme(style='whitegrid')
g = sns.lmplot(
    data=analysis_df,
    x='Addicted_Score',
    y='Mental_Health_Score',
    col='Academic_Level',
    col_order=level_order,
    height=4,
    aspect=0.95,
    scatter_kws={'alpha': 0.55, 's': 30},
    line_kws={'color': 'crimson', 'linewidth': 2}
)

g.set_axis_labels('Addicted Score', 'Mental Health Score')
g.set_titles('{col_name}')
g.fig.subplots_adjust(top=0.82)
g.fig.suptitle('Addicted Score vs Mental Health Score by Academic Level')
plt.show()
# Out:
#                   n  pearson_r  median_addicted_score  \
# Academic_Level
# High School      27     -0.894                    8.0
# Undergraduate   353     -0.940                    7.0
# Graduate        325     -0.948                    7.0
#
#                 median_mental_health_score
# Academic_Level
# High School                            5.0
# Undergraduate                          6.0
# Graduate                               6.0

# %% [markdown]
# **Interpretation**
#
# - Across all academic levels, `Addicted_Score` and `Mental_Health_Score` show a strong negative relationship, as higher addiction score is associated with lower mental health score.
# - The pattern is directionally consistent for High School, Undergraduate, and Graduate students in both the correlation table and regression lines.
# - The High School subgroup has a much smaller sample size (`n = 27`), so its estimated strength should be interpreted more cautiously than the other two groups.

# %% [markdown]
# #### EDA: Gender Stratified Analysis
#
# To investigate whether the relationship between social media addiction and mental health differs between genders, we first visualize the relationship separately for each gender. This helps identify whether gender may moderate the association between addiction score and mental health score.

# %%
gender_order = ['Female', 'Male']

gender_df = ssma[['Gender', 'Addicted_Score', 'Mental_Health_Score']].dropna().copy()
gender_df['Gender'] = pd.Categorical(
    gender_df['Gender'], categories=gender_order, ordered=True
)

gender_stats = (
    gender_df.groupby('Gender', observed=False)
    .agg(
        n=('Addicted_Score', 'size'),
        pearson_r=('Addicted_Score', lambda x: x.corr(gender_df.loc[x.index, 'Mental_Health_Score'])),
        median_addicted_score=('Addicted_Score', 'median'),
        median_mental_health_score=('Mental_Health_Score', 'median')
    )
    .round(3)
)

display(gender_stats)

sns.set_theme(style='whitegrid')
g = sns.lmplot(
    data=gender_df,
    x='Addicted_Score',
    y='Mental_Health_Score',
    col='Gender',
    col_order=gender_order,
    height=4,
    aspect=0.95,
    scatter_kws={'alpha': 0.55, 's': 30},
    line_kws={'color': 'crimson', 'linewidth': 2}
)

g.set_axis_labels('Addicted Score', 'Mental Health Score')
g.set_titles('{col_name}')
g.fig.subplots_adjust(top=0.82)
g.fig.suptitle('Addicted Score vs Mental Health Score by Gender')
plt.show()
# Out:
#           n  pearson_r  median_addicted_score  median_mental_health_score
# Gender
# Female  353     -0.944                    7.0                         6.0
# Male    352     -0.947                    7.0                         6.0

# %% [markdown]
# Interpretation:
#
# - For both female and male students, there is a clear negative linear relationship between Addicted_Score and Mental_Health_Score
#   - As social media addiction increases mental health scores  decrease.
# - The regression lines for both genders are  similar in slope, indicating that the rate at which mental health declines with increasing addiction is nearly the same for males and females
# - The spread of data points around each regression line is also comparable suggesting similar variability in the relationship
# - There is no strong visual evidence of differing intercepts

# %% [markdown]
# #### EDA: Competing Explanatory Variables
#
# We will examine whether each candidate variable is associated with both addiction and mental health. We will then include the candidate variable in the base model and evaluate whether the coefficient of Addicted_Score changes meaningfully (≥10%). Variables that substantially alter the estimated effect will be considered potential confounders or competing explanatory variables.
#
# Some potential candidates we are exploring are `Avg_Daily_Usage_Hours`, `Sleep_Hours_Per_Night`, and `Conflicts_Over_Social_Media`.
#
# Let's first establish the baseline model.

# %%
relationship_mh_v_add = smf.ols(
    'Mental_Health_Score ~ Addicted_Score',
    data=ssma
).fit()
print(relationship_mh_v_add.summary())
baseline_model = relationship_mh_v_add
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     Mental_Health_Score   R-squared:                       0.893
# Model:                             OLS   Adj. R-squared:                  0.893
# Method:                  Least Squares   F-statistic:                     5875.
# Date:                 Thu, 19 Mar 2026   Prob (F-statistic):               0.00
# Time:                         02:53:45   Log-Likelihood:                -282.07
# No. Observations:                  705   AIC:                             568.1
# Df Residuals:                      703   BIC:                             577.3
# Df Model:                            1
# Covariance Type:             nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept         10.4623      0.057    183.833      0.000      10.351      10.574
# ...

# %% [markdown]
# From earlier computation, we obtain the following about **Mental_Health_Score** vs. **Addicted_Score**:
# 1. Correlation: -0.945051
# 2. R-Squared: 0.893
# 3. Coefficient Size: -0.6580
# 4. P-Vlaue of the coefficient: 0.000
#
# Let's first see how correlated the three variables are with `Addicted_Score` and `Mental_Health_Score`

# %%
comp_variables = ['Avg_Daily_Usage_Hours', 'Sleep_Hours_Per_Night', 'Conflicts_Over_Social_Media']

corr_data = {"comparison":['Addicted_Score'],
            "Correlation with Mental_Health_Score":[r],
            "Correlation with Addicted_Score":[1]}
corr_comp_table = pd.DataFrame(data=corr_data).set_index('comparison')

for comp in comp_variables:
    mh_v_comp_corr = ssma['Mental_Health_Score'].corr(ssma[comp])
    add_v_comp_corr = ssma['Addicted_Score'].corr(ssma[comp])

    corr_comp_table.loc[f'{comp}'] = [mh_v_comp_corr, add_v_comp_corr]

corr_comp_table
# Out:
#                              Correlation with Mental_Health_Score  \
# comparison
# Addicted_Score                                          -0.945051
# Avg_Daily_Usage_Hours                                   -0.801058
# Sleep_Hours_Per_Night                                    0.707439
# Conflicts_Over_Social_Media                             -0.893572
#
#                              Correlation with Addicted_Score
# comparison
# Addicted_Score                                      1.000000
# Avg_Daily_Usage_Hours                               0.832000
# Sleep_Hours_Per_Night                              -0.764858
# Conflicts_Over_Social_Media                         0.933586

# %% [markdown]
# Here, we can see that in general all three variables are strongly correlated to both `Mental_Health_Score` and `Addicted_Score`. This also suggests the three variables have a strong linear association. Because potential confounders are typically associated with both the predictor and the outcome, these variables are reasonable candidates for confounding. Therefore, we will then extend the baseline model '`Mental_Health_Score` ~ `Addicted_Score`' by adding each variable to determine whether the coefficient of `Addicted_Score` changes substantially. A meaningful change in the coefficient would indicate that the variable may confound the relationship between `Addicted_Score` and `Mental_Health_Score`.

# %%
formula_comp_curr = {
    "formula": ['Addicted_Score'],
    "r_squared": [relationship_mh_v_add.rsquared],
    "add_coef": [relationship_mh_v_add.params.iloc[1]],
    "% change in add_coef": [0.0],
    "comp_coef": [relationship_mh_v_add.params.iloc[1]],
    "comp_pval": [relationship_mh_v_add.pvalues.iloc[1]]
}

model_comparison = pd.DataFrame(data = formula_comp_curr).set_index('formula')

comp_variables = ['Avg_Daily_Usage_Hours', 'Sleep_Hours_Per_Night', 'Conflicts_Over_Social_Media']
for comp in comp_variables:
    formula = f'Mental_Health_Score ~ Addicted_Score + {comp}'
    relationship = smf.ols(formula, data=ssma).fit()
    rsquared = relationship.rsquared
    new_add_coef = relationship.params.iloc[1]
    change_in_add_coef = (new_add_coef - model_comparison.loc['Addicted_Score', 'add_coef'])/model_comparison.loc['Addicted_Score', 'add_coef']*100
    comp_coef = relationship.params.iloc[2]
    comp_pval = relationship.pvalues.iloc[2]
    
    model_comparison.loc[f'Addicted_Score + {comp}'] = [rsquared, new_add_coef, change_in_add_coef, comp_coef, comp_pval]

# %%
model_comparison
# Out:
#                                               r_squared  add_coef  \
# formula
# Addicted_Score                                 0.893121 -0.657987
# Addicted_Score + Avg_Daily_Usage_Hours         0.893830 -0.630178
# Addicted_Score + Sleep_Hours_Per_Night         0.893692 -0.677737
# Addicted_Score + Conflicts_Over_Social_Media   0.894113 -0.600860
#
#                                               % change in add_coef  comp_coef  \
# formula
# Addicted_Score                                            0.000000  -0.657987
# Addicted_Score + Avg_Daily_Usage_Hours                   -4.226400  -0.042191
# Addicted_Score + Sleep_Hours_Per_Night                    3.001572  -0.036370
# Addicted_Score + Conflicts_Over_Social_Media             -8.681980  -0.101380
#
#                                               comp_pval
# formula
# Addicted_Score                                 0.000000
# Addicted_Score + Avg_Daily_Usage_Hours         0.030674
# ...

# %% [markdown]
# By creating the above comparison table, we can see the following things:
#
# 1. `r_squared`: how much of the variance of y is explained by the formula
# 2. `add_coef`: the coefficient of the `Addicted_Score` after revision of formula
# 3. `% change in add_coef`: the percent change between the coefficient of the `Addicted_Score` in revised and the baseline.
# 4. `comp_coef`: the coefficient of the newly added variable.
# 5. `comp_pval`: the p-value of the  newly added variable.
#
# For the addition of `Avg_daily_Usage_Hours`, compared to the baseline, we see that the `Addicted_Score` coefficient decreased 4.23% in magnitude. This suggests, `Avg_Daily_Usage_hours` does not substantially change the estimated effect of `Addicted_Score`.
#
# For the addition of `Sleep_Hours_Per_Night`, compared to the baseline, we see that the `Addicted_Score` coefficient increased 3% in magnitude. This suggests, `Sleep_Hours_Per_Night` does not substantially change the estimated effect of `Addicted_Score`.
#
# For the addition of `Conflicts_Over_Social_Media`, compared to the baseline, we see that the `Addicted_Score` coefficient decreased 8.68% in magnitude. This suggests, `Conflicts_Over_Social_Media`does not substantially change the estimated effect of `Addicted_Score`.
#
# If we observe the p_value of the new variables, we find most are statstically associated associated with `Mental_Health_Score`, with the exception of `Sleep` (greater than 0.05 by a sliver). However, they do not contribute as seen by the miniscule change in r_squared.
#
# In conclusion, while we discovered strong linear association of the three variables with `Mental_Health_Score` and `Addicted_Score`, we discover no significant change in the coefficients of `Addicted_Score` after extending them individually to the baseline regression model. This suggests that these variables do not meaningful contribute to the association between `Mental_Health_Score` and `Addicted_Score` in this dataset.

# %% [markdown]
# ### Data Analysis
#
# Following the exploratory data analysis (EDA), several preliminary patterns emerged regarding the relationship between social media addiction and mental health, which remained evident when the data were stratified by gender and academic level. Boxplots by gender showed that male and female students report broadly similar addiction levels, with comparable medians and interquartile ranges, though females exhibited slightly higher upper-end scores while males showed slightly greater variability and a few outliers. Stratified analysis by academic level further reinforced the overall pattern: scatterplots and regression lines within each subgroup (High School, Undergraduate, and Graduate) all displayed the same negative trend, indicating that higher addiction scores are associated with lower mental health scores across educational stages. Although the High School subgroup has a smaller sample size and should be interpreted with greater caution, the direction of the relationship remains consistent.
#
# To formally evaluate our research question and hypothesis, we proceed with a series of analyses grouped under Data Analysis, which include ordinary least squares (OLS) regression and permutation testing. As an initial step, we briefly revisit the baseline OLS regression model—previously introduced during the EDA when examining competing explanatory variables—which models `Mental_Health_Score` as a function of `Addicted_Score`. This baseline model provides a quantitative reference point for the strength of the overall relationship before extending the analysis to more detailed statistical testing.

# %% [markdown]
# #### OLS Regression: Baseline Model of Mental Health Score vs. Addiction Score
#
# The baseline association between `Addicted_Score` and `Mental_Health_Score` is very strong and negative. In this dataset, the correlation is `-0.945`, the model `R^2` is `0.893`, and the slope on `Addicted_Score` is `-0.658` with `p < 0.001`. This indicates that a one-point increase in social media addiction score is associated with about a `0.66` point decrease in mental health score on average, providing strong evidence that higher addiction levels are linked to worse mental health outcomes.

# %%
baseline_results = pd.DataFrame({
    'Metric': ['Correlation', 'R-squared', 'Intercept', 'Addicted_Score coefficient', 'Addicted_Score p-value'],
    'Value': [
        ssma['Addicted_Score'].corr(ssma['Mental_Health_Score']),
        baseline_model.rsquared,
        baseline_model.params['Intercept'],
        baseline_model.params['Addicted_Score'],
        baseline_model.pvalues['Addicted_Score'],
    ],
})

baseline_results.round(4)
# Out:
#                        Metric    Value
# 0                 Correlation  -0.9451
# 1                   R-squared   0.8931
# 2                   Intercept  10.4623
# 3  Addicted_Score coefficient  -0.6580
# 4      Addicted_Score p-value   0.0000

# %% [markdown]
# #### OLS Regression: Interaction Models by Gender and Academic Level
#
# This analysis examined whether the relationship between social media addiction and mental health differs by gender and academic level using interaction regression models.
#
# For gender, the interaction term is small and not statistically significant (`beta = -0.029`, `p = 0.094`), which suggests that the negative relationship between addiction score and mental health score is similar for male and female students. For academic level, the high school interaction term is significant (`beta = 0.221`, `p < 0.001`) and the undergraduate interaction is marginal (`p = 0.053`), indicating that academic level partially moderates this relationship. In particular, the association appears weaker for high school students relative to the graduate-student reference group.

# %%
gender_interaction_model = smf.ols(
    'Mental_Health_Score ~ Addicted_Score * Gender',
    data=ssma
).fit()

academic_interaction_model = smf.ols(
    'Mental_Health_Score ~ Addicted_Score * Academic_Level',
    data=ssma
).fit()

interaction_results = pd.DataFrame([
    {
        'Model': 'Gender interaction',
        'Term': 'Addicted_Score:Gender[T.Male]',
        'Coefficient': gender_interaction_model.params['Addicted_Score:Gender[T.Male]'],
        'p-value': gender_interaction_model.pvalues['Addicted_Score:Gender[T.Male]'],
        'R-squared': gender_interaction_model.rsquared,
    },
    {
        'Model': 'Academic level interaction',
        'Term': 'Addicted_Score:Academic_Level[T.High School]',
        'Coefficient': academic_interaction_model.params['Addicted_Score:Academic_Level[T.High School]'],
        'p-value': academic_interaction_model.pvalues['Addicted_Score:Academic_Level[T.High School]'],
        'R-squared': academic_interaction_model.rsquared,
    },
    {
        'Model': 'Academic level interaction',
        'Term': 'Addicted_Score:Academic_Level[T.Undergraduate]',
        'Coefficient': academic_interaction_model.params['Addicted_Score:Academic_Level[T.Undergraduate]'],
        'p-value': academic_interaction_model.pvalues['Addicted_Score:Academic_Level[T.Undergraduate]'],
        'R-squared': academic_interaction_model.rsquared,
    },
])

interaction_results.round(4)
# Out:
#                         Model                                            Term  \
# 0          Gender interaction                   Addicted_Score:Gender[T.Male]
# 1  Academic level interaction    Addicted_Score:Academic_Level[T.High School]
# 2  Academic level interaction  Addicted_Score:Academic_Level[T.Undergraduate]
#
#    Coefficient  p-value  R-squared
# 0      -0.0292   0.0941     0.8935
# 1       0.2206   0.0006     0.8955
# 2       0.0345   0.0528     0.8955

# %% [markdown]
# Let's look deeper into specific models, starting with gender interaction.

# %%
print(gender_interaction_model.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     Mental_Health_Score   R-squared:                       0.894
# Model:                             OLS   Adj. R-squared:                  0.893
# Method:                  Least Squares   F-statistic:                     1961.
# Date:                 Thu, 19 Mar 2026   Prob (F-statistic):               0.00
# Time:                         02:53:55   Log-Likelihood:                -280.66
# No. Observations:                  705   AIC:                             569.3
# Df Residuals:                      701   BIC:                             587.5
# Df Model:                            3
# Covariance Type:             nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %%
sns.lmplot(
    data=ssma,
    x='Addicted_Score',
    y='Mental_Health_Score',
    hue='Gender',
    ci=None
)

# %% [markdown]
# ##### Gender Interaction Results
# The interaction between Addicted_Score and Gender was not statistically significant (β = -0.029, p = .094).
#
# This indicates that:
#
# The negative relationship between addiction and mental health is similar for males and females.
#
# Although slopes appear slightly different visually, the difference is not statistically meaningful at the .05 level.
#
# Conclusion:
# Gender does not significantly moderate the relationship between social media addiction and mental health.

# %% [markdown]
# Now, let's focus on the academic level interaction.

# %%
print(academic_interaction_model.summary())
# Out:
#                              OLS Regression Results
# ...
# Dep. Variable:     Mental_Health_Score   R-squared:                       0.896
# Model:                             OLS   Adj. R-squared:                  0.895
# Method:                  Least Squares   F-statistic:                     1198.
# Date:                 Thu, 19 Mar 2026   Prob (F-statistic):               0.00
# Time:                         02:54:00   Log-Likelihood:                -274.08
# No. Observations:                  705   AIC:                             560.2
# Df Residuals:                      699   BIC:                             587.5
# Df Model:                            5
# Covariance Type:             nonrobust
# ...
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ##### Academic Level Interaction Results
# The interaction between Addicted_Score and Academic_Level showed mixed results:
#
# High School interaction term was significant (β = 0.221, p = .001)
#
# Undergraduate interaction term was marginal (p = .053)
#
# This suggests that:
#
# The strength of the addiction–mental health relationship differs for high school students compared to the reference group.
#
# The negative impact of addiction on mental health is weaker for high school students than for the reference academic level.
#
# Conclusion:
# Academic level partially moderates the relationship, particularly for high school students.

# %% [markdown]
# ##### Overall Interpretation
#
# Social media addiction strongly predicts poorer mental health.
#
# This relationship does not differ by gender.
#
# It does differ somewhat by academic level, especially for high school students.

# %% [markdown]
# #### Permutation Test: Addiction vs Mental Health
#
# The permutation test showed a strong negative relationship between social media addiction and mental health scores. The observed correlation between addiction score and mental health score was r = -0.945. After generating 10,000 permutations of the mental health scores, none of the permuted correlations were as extreme as the observed correlation, resulting in a permutation p-value ≈ 0.000 (p < 0.001). This indicates that the observed correlation is highly unlikely to occur by chance. Therefore, the results suggest a statistically significant negative relationship between social media addiction and mental health, meaning that higher addiction scores are associated with lower mental health scores.

# %%
obs_corr = ssma["Addicted_Score"].corr(ssma["Mental_Health_Score"])

n_perm = 10000
perm_corrs = []

for i in range(n_perm):
    shuffled = np.random.permutation(ssma["Mental_Health_Score"])
    perm_corr = np.corrcoef(ssma["Addicted_Score"], shuffled)[0,1]
    perm_corrs.append(perm_corr)

p_value = np.mean(np.abs(perm_corrs) >= abs(obs_corr))

print("Observed correlation:", obs_corr)
print("Permutation p-value:", p_value)
# Out:
# Observed correlation: -0.9450506757277399
# Permutation p-value: 0.0

# %%
plt.hist(perm_corrs, bins=40)

plt.axvline(obs_corr)

plt.title("Permutation Test: Social Media Addiction vs Mental Health")

plt.xlabel("Correlation between Addiction Score and Mental Health Score")
plt.ylabel("Number of Permutations")

plt.show()

# %% [markdown]
# #### Permutation Test: Does the Correlation Differ by Gender?
#
# A permutation test was conducted to examine whether the relationship between social media addiction and mental health differs by gender. The observed difference in correlation between male and female students was -0.0025. After randomly permuting the gender labels 10,000 times, the permutation test produced a p-value of 0.7334. Because this p-value is much larger than 0.05, the observed difference in correlations is likely due to random variation. Therefore, the results suggest that the relationship between social media addiction and mental health does not significantly differ between male and female students.

# %%
male = ssma[ssma["Gender"] == "Male"]
female = ssma[ssma["Gender"] == "Female"]

r_male = male["Addicted_Score"].corr(male["Mental_Health_Score"])
r_female = female["Addicted_Score"].corr(female["Mental_Health_Score"])

obs_diff = r_male - r_female
obs_diff
# Out:
# -0.0025266657770193213

# %%
perm_diffs = []

for i in range(10000):
    
    shuffled_gender = np.random.permutation(ssma["Gender"])
    ssma["perm_gender"] = shuffled_gender
    
    m = ssma[ssma["perm_gender"] == "Male"]
    f = ssma[ssma["perm_gender"] == "Female"]
    
    diff = m["Addicted_Score"].corr(m["Mental_Health_Score"]) - \
           f["Addicted_Score"].corr(f["Mental_Health_Score"])
    
    perm_diffs.append(diff)

p_value_gender = np.mean(np.abs(perm_diffs) >= abs(obs_diff))

print("Observed difference:", obs_diff)
print("Permutation p-value:", p_value_gender)
# Out:
# Observed difference: -0.0025266657770193213
# Permutation p-value: 0.7334

# %%
plt.figure(figsize=(8,5))

sns.histplot(perm_diffs, bins=40)

plt.axvline(obs_diff, linestyle='--')

plt.title("Permutation Test: Correlation Difference by Gender")
plt.xlabel("Permuted Difference in Correlation (Male − Female)")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# #### Permutation Test — Does the Correlation Differ by Academic Level?
#
# A permutation test was conducted to examine whether the relationship between social media addiction and mental health differs across academic levels. The observed difference between the highest and lowest correlations across academic groups was 0.0544. After randomly permuting the academic level labels 10,000 times, the permutation test produced a p-value of 0.0199. Since this p-value is below 0.05, the observed difference is unlikely to occur by chance. However, because the High School subgroup is substantially smaller than the undergraduate and graduate groups, its correlation estimate is less stable. Therefore, the observed difference should be interpreted with caution.

# %%
groups = ssma["Academic_Level"].unique()

corrs = {}

for g in groups:
    sub = ssma[ssma["Academic_Level"] == g]
    corrs[g] = sub["Addicted_Score"].corr(sub["Mental_Health_Score"])

obs_stat = max(corrs.values()) - min(corrs.values())

# %%
perm_stats = []

for i in range(10000):
    
    shuffled = np.random.permutation(ssma["Academic_Level"])
    ssma["perm_level"] = shuffled
    
    corrs = []
    
    for g in groups:
        sub = ssma[ssma["perm_level"] == g]
        corrs.append(sub["Addicted_Score"].corr(sub["Mental_Health_Score"]))
    
    stat = max(corrs) - min(corrs)
    perm_stats.append(stat)

p_value_level = np.mean(np.array(perm_stats) >= obs_stat)

print("Observed difference:", obs_stat)
print("Permutation p-value:", p_value_level)
# Out:
# Observed difference: 0.05437971368769279
# Permutation p-value: 0.0199

# %%
plt.figure(figsize=(8,5))

sns.histplot(perm_stats, bins=40)

plt.axvline(obs_stat, linestyle='--')

plt.title("Permutation Test: Correlation Difference by Academic Level")
plt.xlabel("Permuted Difference in Correlations")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# #### Analysis Conclusion
#
# Overall, the analysis provides strong evidence of a statistically significant negative relationship between social media addiction and mental health scores among students. The baseline OLS regression shows a very strong association ($r=−0.945$, $R^2=0.893$, $p<0.001$), indicating that higher addiction scores are consistently associated with lower mental health scores. This finding is further supported by the permutation test, which confirms that the observed correlation is highly unlikely to occur by chance ($p<0.001$). Together, these results strongly support the first part of the research question: social media addiction and mental health are significantly related in this dataset.
#
# However, the evidence for differences in this relationship across demographic groups is mixed. The gender interaction model and permutation test both suggest that the association between addiction and mental health does not significantly differ between male and female students. In contrast, academic level shows some evidence of moderating the relationship, with both the interaction regression and permutation test indicating a statistically significant difference across academic groups. Nevertheless, because the High School subgroup is much smaller than the others, its correlation estimate is less stable and should be interpreted cautiously. Overall, while the primary hypothesis that addiction is negatively associated with mental health is strongly supported, the hypothesis that this relationship clearly differs by gender and academic level is only partially supported, with meaningful differences appearing mainly across academic levels rather than gender.

# %% [markdown]
# ## Ethics
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > Since the data is collected from a survey administered through university mailing lists and social-media platforms, data should be provided voluntarily by participants. If at any point subjects felt uncomfortable, continuing with the survey would be voluntary.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > Countries with higher populations are likely to have more rows in the dataset, independent of development level. This can be mitigated by normalization. Since the survey is administered online, there is a bias for students with reliable internet access, which could in turn also depend on the country; students from more developed countries are more likely to have internet access. For this, we plan to verify any actual correlations and then take further steps from there on out, possibly analyzing groups of specific countries at a time. Nevertheless, these biases cause students with internet access and living in well-developed communities to be favored, and hence could impose unfair practices (such as restrictions on internet access) on students from communities with not as many resources readily available, affecting their access to information. For example, communities not knowledgable enough about social media may believe the adverse affects of social media are from using the internet overall, not just social media.
#
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# > The only identifiable data column in our dataset is the `Student_ID`, which is used to keep track of duplicate submissions. As long as that does not have any connection to the actual student ID of a student, there is no risk of exposure. Considering `Student_ID` is numbered incrementally (1-705), there should be no relation present with the student's identifiable information. However, 79 out of 110 countries only have one submission, which could potentially be used to identify students who filled out the survey. Hence, we would want to be more careful for country-wise analyses, making sure sufficient aggregations are made to hide any identifiable statistics.
#
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
#  > Looking at the data, some countries dominate over others, which could be an issue if there are major cultural differences between them. Again, normalization could be a way to fix this. Also, we might do analysis by platform too, since most of the dataset is dominated by Instagram, TikTok, and Facebook (in that order). This would help not skew results, since it is very likely that many mental health concerns are caused by specific popular platforms rather than social media in general. This could ruin the reputation of social media platforms that can actually be useful to people, such as YouTube.
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# > No personably identifiable data is stored. We cannot delete a person's data if we cannot identify them in the first place.
#
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > Since some countries and some communities (because of factors like internet access, number of college students in region) are overrepresented in the dataset, if our findings were to be used to implement policies, they might not generalize well to all regions. Moreover, since some platforms dominate the dataset, findings would be skewed towards perceived effect of those platforms as compared to all social media in general. Since much of the data is self-reported, there might be a bias towards median values since that is how humans usually rate things; 1 or 10 are only given in case of extremes, each person having a different threshold. Additionally, depending on the current situation of the person filling out the survey, they might give higher or lower ratings than their usual self would, potentially skewing results. For example, students are much more likely to be stressed out and lack sleep during exam season, which can vary depending on the country and the university.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > Even though the data does seem to follow a normal distribution for `Mental_Health_Score`, there might be some bias. Because the survey was completely voluntary, there is a chance people who are more likely to believe they have some mental health problems are also more likely to fill out the survey. Moreover, since the top two countries are India and USA, both of which contribute to disproportionately large amount of content to the internet, students from these countries are not only more likely to fill out the survey but also be more affected by social media, since their culture would allow them to connect with more of the content they see online.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > All of us have experience with data visualization.
#
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# > So far, yes.
#
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > We are using a publicly available dataset. As long as we follow good practices, our results should be reproducible for college students.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# > Because of overrepresentation of certain countries and certain platforms, normalizing would be the best option to solve any issues that arise related to Fairness. The goal is to make our findings as generalizable as possible.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We are taking into account possible biases, and have explained them in this section.
#
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# > Using techniques such as normalizaing and aggregation, we hope to account for any overrepresentation present in the dataset. This is to make sure that any policies introduced in schools do not cause more harm than good. For example, a boarding school using our findings may ban YouTube for its students, even though that is used by many as a learning resource and isn't even most people's most used platform.
#
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > We will emphasize how our findings cannot be generalized to all regions, and that each institution or government will have to decide for themselves using their own data what policies should be implemented to improve students' mental health.
#
# It should be noted that our project does not include any actual modeling. Hence, not all questions in D and E are relevent to our project.

# %% [markdown]
# ## Team Expectations
#
# * Communication will be done through Discord. Check it as frequently as possible, but at least twice a day.
# * If you know you are about to be busy, notify the team *before* you are. That way, we can reallocate the workload for the week in advance and stay on track.
# * When providing criticism, make sure to keep it constructive. Specify clearly whether something is your opinion, belief from past experiences, or general advice.
# * Decisions will be made after a group discussion, usually after a group call.
# * Weekly meetings will be held on mondays to decide work for the rest of the week.

# %% [markdown]
# ## Project Timeline Proposal
#
# | Date | Time | Completed Before Meeting | Discuss at Meeting |
# |------|------|--------------------------|--------------------|
# | **Mar 4** | **4:00–5:00 PM** | **Checkpoint #2: EDA Due — finalized exploratory analysis; complete summary statistics table with real numbers; clearly document variable definitions; report dataset size (total and analytic N); state preliminary limitations** | **Review EDA findings; confirm modeling direction; verify data description is now fully complete and no placeholders remain** |
# | Mar 6 | 4:00–5:00 PM | Draft Results section; clearly report dataset size in every model; ensure statistical findings match tables; avoid causal overstatement | Edit for clarity; refine explanation of results |
# | Mar 8 | 4:00–5:00 PM | Draft expanded Ethics & Limitations section (measurement limits, sampling bias, confounding, generalizability, misuse risks); explicitly connect limitations to findings | Review ethical framing; strengthen discussion of misinterpretation risks |
# | Mar 11 | 4:00–5:00 PM | Compile full project notebook; include clean summary statistics table; verify variable definitions; ensure consistent N reporting; clean and comment code | Conduct full walkthrough; debug; check clarity and coherence |
# | Mar 13 | 4:00–5:00 PM | Revise notebook based on feedback; polish writing and figures; confirm no placeholder text remains; cross-check all numbers for consistency | Ensure all rubric elements are fully addressed |
# | Mar 15 | 4:00–5:00 PM | Final review; verify dataset size, measurement explanations, and summary statistics are clearly stated and consistent; proofread for causal language | Confirm submission readiness; final completeness check |
# | **Mar 18** | **By 11:59 PM** | NA | **Submit final project and complete group project surveys** |

# %% [markdown]
# ## Discusison and Conclusion
#
# Wrap it all up here.  Somewhere between 3 and 10 paragraphs roughly.
# 1. Summarize the important results you made
# 2. This is a good time to refer back to your Background section and review how this work extended the previous stuff.
# 3. Try to bring all the different results together into a bigger picture... what have we learned?
# 4. Often what we learned is confusing.  Discuss if there are contradictory results how that might have happened
# 5. Discuss the limitations of your work. e.g, is the dataset a biased sample? would more data make you more confident? would longitudinal instead of cross-sectional data helpful? is there evidence that the phenomena you're investigating may change over time? etc
# 6. If you would like, you can also say what the next steps in this investigation might be if the work was to continue outside this class

# %% [markdown]
# ## Discussion and Conclusion
#
# As social media has become more popular in recent years, its effects have become more prevalent in society. While it is widely believed that social media has adverse effects on the mental health of its users, past studies have usually focused solely on the time spent online. Research has shown that screen time alone is not always a good measure of the effects of social media, since those depend much more on factors such as engagement with harmful material. Recent work has fortunately shifted to focus more on examining the quality and consequences of social media use, examining how exactly it affects and conflicts with one’s life. College students tend to be very active on social media, and hence we aimed our project to explore the relations between social media usage and mental health, potentially exploring how social media addiction can disrupt daily life.
#
# Our research question specifically asks whether there is a statistically significant relationship between social media addiction scores and mental health scores, and whether this is influenced by gender and/or academic level. From our past research, excessive social media usage can contribute to things like fear and detachment. Our variables of focus from our dataset were `Addicted_Score` and `Mental_Health`Score, `Academic Level`, and `Gender`, with `Academic_Level` and `Gender` being possible influences. We first explored relations between solely `Addicted_Score` and `Mental_Health_Score`, which showed a very strong negative correlation with a Pearson coefficient of $-0.945$ and an $R^2$ of $0.893$, confirming that social media addiction does contribute to worse mental health. Adding `Gender` to the equation, there was no statistically significant difference between males and females. Adding `Academic_Level`, while the relationship did somewhat differ for high-school students compared to other categories, because of the small sample size for high school students, this should be interpreted with caution. Lastly, we ran permutation tests to explore the relations between Social Media Addiction and Mental Health scores, and also compared correlations of Addiction scores with Gender and Academic level. As from before, addiction and mental health score correlations are statistically significant, gender correlations are not, and academic level is (but this should be taken with a grain of salt because of the small sample size of high school students).
#
# Overall, we wanted to explore whether factors other than just social media addiction were responsible for mental health amongst college students. While our project does present statistically significant findings, `Addicted_Score` and `Mental_Health_Score` are self-reported. This means even after accounting for biases of the demographics of students who filled out the survey, there are still Likert Scale problems of how extreme ratings are much less likely to be reported, leading to bell-shaped distributions as noted during our EDA. In the future, we would want to use a dataset that has more robust measures of mental health scoring and social media addiction levels. Additionally, we wish to explore longitudnal data sources that can track mental health and addiction over time, to observe the actual long-term effects of social media usage. This might also reveal more differences between variables such as gender, which might not be visible in a single time snapshot.
